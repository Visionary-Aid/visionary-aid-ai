# %%
# !pip install gtts

# %%
# استيراد المكتبات
from google.colab import files
import sys
import os

# رفع الصورة من جهازك إلى Colab
uploaded = files.upload()

# اسم الصورة المرفوعة
image_path = list(uploaded.keys())[0]  # الحصول على اسم الصورة المرفوعة

# استيراد السكربت بعد التحويل
from main_app import check_image_exists

# التحقق من وجود الصورة
check_image_exists(image_path)


# استيراد المكتبات
from google.colab import files
import sys
import os

# رفع الصورة من جهازك إلى Colab
uploaded = files.upload()

# اسم الصورة المرفوعة
image_path = list(uploaded.keys())[0]  # الحصول على اسم الصورة المرفوعة

# استيراد السكربت بعد التحويل
#from main_app import check_image_exists
# Assuming check_image_exists is defined in the current notebook
# or in a file named main_app.py that is in the same directory

# if the function is in a separate .py file in the same directory:
# import main_app
# then use: main_app.check_image_exists(image_path)


# if check_image_exists is defined in the current notebook then use
# the code below directly.

#def check_image_exists(image_path):
#    if os.path.exists(image_path):
#        print(f"The image '{image_path}' exists.")
#    else:
#        print(f"The image '{image_path}' does not exist.")


# التحقق من وجود الصورة
#check_image_exists(image_path)
try:
    # Assuming check_image_exists is in main_app.py in the same directory as this notebook
    import main_app
    main_app.check_image_exists(image_path)
except ImportError:
    print("Error: 'main_app' not found. Make sure it's in the same directory and is importable.")
    # or provide an alternative implementation for check_image_exists
    if os.path.exists(image_path):
        print(f"The image '{image_path}' exists.")
    else:
        print(f"The image '{image_path}' does not exist.")
except AttributeError:
    print("Error: check_image_exists not found in main_app")
    if os.path.exists(image_path):
        print(f"The image '{image_path}' exists.")
    else:
        print(f"The image '{image_path}' does not exist.")
# استيراد المكتبات
from google.colab import files
import sys
import os

# رفع الصورة من جهازك إلى Colab
uploaded = files.upload()

# اسم الصورة المرفوعة
image_path = list(uploaded.keys())[0]  # الحصول على اسم الصورة المرفوعة

# استيراد السكربت بعد التحويل
#from main_app import check_image_exists
# Assuming check_image_exists is defined in the current notebook
# or in a file named main_app.py that is in the same directory

# if the function is in a separate .py file in the same directory:
# import main_app
# then use: main_app.check_image_exists(image_path)


# if check_image_exists is defined in the current notebook then use
# the code below directly.

#def check_image_exists(image_path):
#    if os.path.exists(image_path):
#        print(f"The image '{image_path}' exists.")
#    else:
#        print(f"The image '{image_path}' does not exist.")


# التحقق من وجود الصورة
#check_image_exists(image_path)
try:
    # Assuming check_image_exists is in main_app.py in the same directory as this notebook
    import main_app
    main_app.check_image_exists(image_path)
except ImportError:
    print("Error: 'main_app' not found. Make sure it's in the same directory and is importable.")
    # or provide an alternative implementation for check_image_exists
    if os.path.exists(image_path):
        print(f"The image '{image_path}' exists.")
    else:
        print(f"The image '{image_path}' does not exist.")
except AttributeError:
    print("Error: check_image_exists not found in main_app")
    if os.path.exists(image_path):
        print(f"The image '{image_path}' exists.")
    else:
        print(f"The image '{image_path}' does not exist.")
# Out:
#      <input type="file" id="files-d1926830-1ee7-41d5-a7d0-8d7874a64d9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1926830-1ee7-41d5-a7d0-8d7874a64d9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
